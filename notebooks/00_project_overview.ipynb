# %% [markdown]
# # NeuroForge project overview
#
# **Objective:** test whether computation can be allocated per sample.
#
# **Research question:** can learned routing improve the accuracy–compute trade-off over fixed models?
#
# This notebook is intentionally an overview. Reusable code lives in `src/neuroforge`; see `04_router_toy_experiment.ipynb` for execution.

# %%
from neuroforge.config import NeuroForgeConfig
config = NeuroForgeConfig.from_yaml('../configs/base.yaml')
config

# %% [markdown]
# ## Interpretation
#
# The package reports estimated computation and observed latency separately. A soft route is differentiable, but it evaluates every block; only hard dispatch can skip work physically. Review `docs/research/experiment-protocol.md` before interpreting a result.
