# %% [markdown]
# # Phase 3: Capacity-Matched Expert Specialization
#
# Research question: do the existing NeuroForge primitives have relative strengths on feature, relational, and content-addressed contextual tasks? Phase 1 routing failure and Phase 2 router learnability are preserved evidence.
#
# The experiment uses standalone wrappers around unchanged blocks, deterministic capacity search, cross-evaluation, shortcut probes, and structural controls. The graph control is node-feature permutation relative to its internally fixed ring; it is not literal external edge randomization.

# %%
from neuroforge.training import run_expert_specialization
result = run_expert_specialization('results/metrics/phase3_expert_specialization')
result['matrix'], result['capacity'], result['controls']
