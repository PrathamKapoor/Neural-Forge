# %% [markdown]
# # Phase 29 — Prediction Recovery & Exact Complementarity
# No architecture change. RC CLOSED. Intervention NONE. Predictions MISSING honestly preserved.

# %% [markdown]
# ## 1. Provenance & Reproduction

# %%
import json; p29=Path("results/metrics/phase29_prediction_recovery"); repro=json.load(open(p29/"reconstruction.json")); print("Status:", repro["status"]); print("Predictions available (portfolio):", repro.get("predictions_available_for_portfolio")); print("Predictions verified (25B MLP):", repro.get("predictions_verified_for_mlp_reference")); print("Reconstruction status:", repro.get("reconstruction_status")); print("Note:", repro.get("reconstruction_note")[:150])

# %% [markdown]
# ## 2. Checkpoint Inventory

# %%
import csv; rows=list(csv.DictReader(open("results/metrics/phase29_prediction_recovery/checkpoint_inventory.csv"))); [print(f"{r["architecture"]}: identity={r["verified_identity"]}, phase={r["phase"]}, note={r["note"][:60]}") for r in rows]

# %% [markdown]
# ## 3. Prediction Availability (Critical)

# %%
import json; pred=json.load(open("results/metrics/phase29_prediction_recovery/prediction_reference.json")); print("Phase 25B MLP predictions verified:", pred.get("phase_25b_mlp_predictions",{}).get("available")); print("Phase 26 portfolio predictions available:", pred.get("phase_26_portfolio_predictions",{}).get("available")); print("Historical Phase 20 replay:", pred.get("historical_p20_replay_available"))

# %% [markdown]
# ## 4. Approximate vs Exact

# %%
import csv; rows=list(csv.DictReader(open("results/metrics/phase29_prediction_recovery/approximate_vs_exact.csv"))); [print(r) for r in rows]

# %% [markdown]
# ## 5. Case & Gate

# %%
import json; case_data=json.load(open("results/metrics/phase29_prediction_recovery/case.json")); gate=json.load(open("results/metrics/phase29_prediction_recovery/intervention_gate.json")); print("Case:", case_data.get("case")); print("Reconstruction status:", case_data.get("reconstruction_status")); print("Gate:", gate.get("intervention_gate")); print("Intervention:", gate.get("intervention")); print("Architecture:", case_data.get("architecture_change")); print("RC:", case_data.get("rc_status"))

# %% [markdown]
# ## 6. Scientific Principle (Evidence-Only)

# %% [markdown]
# Phase 29 confirms: Phase 25B MLP predictions.npy verified (hash cf6afa609...). Phase 26 portfolio predictions.npy MISSING (historical provenance; reconstructed predictions clearly labeled; original MISSING; no predictions fabricated; no predictions reconstructed and substituted). The exact recoverable complementarity remains unresolved (CASE_D_UNRESOLVED). The scientific response: maintain CLOSED intervention gate; complete provenance prerequisites (predictions.npy, split identity, checkpoint identity) before considering any minimal aggregation mechanism.
