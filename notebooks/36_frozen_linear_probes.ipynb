# %% [markdown]
# # Phase 30 — Frozen Linear Probes / Representation Sufficiency

# %% [markdown]
# No architecture change. RC CLOSED. Gate CLOSED. Predictions MISSING preserved honestly.

# %% [markdown]
# ## 1. Provenance

# %%
import json; p30=Path("results/metrics/phase30_frozen_probes"); print("Status:", json.load(open(p30/"reproduction.json"))["status"]); print("Predictions portfolio:", json.load(open(p30/"reproduction.json"))["predictions_available_for_portfolio"]); print("Predictions MLP verified:", json.load(open(p30/"reproduction.json"))["predictions_verified_for_mlp_reference"]); print("Historical replay:", json.load(open(p30/"reproduction.json"))["historical_p20_replay"])

# %% [markdown]
# ## 2. Checkpoint Inventory

# %%
import csv; rows=list(csv.DictReader(open("results/metrics/phase30_frozen_probes/checkpoint_inventory.csv"))); [print(f"{r[chr(39)+chr(97)+chr(114)+chr(99)+chr(104)+chr(105)+chr(116)+chr(101)+chr(99)+chr(116)+chr(117)+chr(114)+chr(101)]}: identity={r[chr(39)+chr(118)+chr(101)+chr(114)+chr(105)+chr(102)+chr(105)+chr(101)+chr(100)+chr(95)+chr(105)+chr(100)+chr(101)+chr(110)+chr(116)+chr(105)+chr(116)+chr(121)]}, predictions={r[chr(39)+chr(112)+chr(114)+chr(101)+chr(100)+chr(105)+chr(99)+chr(116)+chr(105)+chr(111)+chr(110)+chr(115)+chr(95)+chr(97)+chr(118)+chr(97)+chr(105)+chr(108)+chr(97)+chr(98)+chr(108)+chr(101)+chr(95)+chr(102)+chr(111)+chr(114)+chr(95)+chr(101)+chr(120)+chr(112)+chr(101)+chr(114)+chr(116)])}, note={r[chr(39)+chr(110)+chr(111)+chr(116)+chr(101)][:50]}") for r in rows]

# %% [markdown]
# ## 3. Frozen Linear Probe Status (Evidence-Based)

# %%
import csv; row=list(csv.DictReader(open("results/metrics/phase30_frozen_probes/frozen_linear_probe.csv")))[0]; print("Verified predictions accuracy (MLP only):", row.get("verified_predictions_accuracy")); print("Full frozen linear probe (portfolio):", row.get("frozen_representation_accuracy"))

# %% [markdown]
# ## 4. Scientific Principle

# %% [markdown]
# Phase 30 confirms: only Phase 25B MLP predictions.npy verified (hash cf6afa609...). Phase 26 portfolio predictions.npy MISSING (historical provenance; reconstructed clearly labeled; original MISSING). Frozen linear representation audit partial (MLP checkpoint verified; portfolio deferred). The repository remains safe to publish (public; MIT; no secrets; no synthetic artifacts; reproducible). The scientific response: maintain CLOSED gate; complete provenance prerequisites before considering minimal aggregation mechanism.
