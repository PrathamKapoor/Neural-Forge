# %% [markdown]
# # Phase 30c - Actual Frozen MLP Probe
# Status: COMPLETE (corrective continuation of Phase 30) | Case: CASE_D_UNRESOLVED | Architecture: NONE | RC: CLOSED | Gate: CLOSED | Predictions portfolio: MISSING (honestly preserved)

# %% [markdown]
# ## 1. Provenance Verification

# %%
import json; p30c=__import__('pathlib').Path('results/metrics/phase30c_frozen_linear_probes'); repro=json.load(open(p30c/'reproduction.json')); print('Status:',repro.get('status')); print('Predictions portfolio available:',repro.get('predictions_available_for_portfolio')); print('Predictions MLP verified:',repro.get('predictions_available_for_mlp_reference'))

# %% [markdown]
# ## 2. Frozen Linear Probe (Actual Execution - MLP Only)

# %%
import csv; row=list(csv.DictReader(open('results/metrics/phase30c_frozen_linear_probes/frozen_linear_probe.csv')))[0]; print('Verified predictions accuracy:',row.get('verified_predictions_accuracy')); print('Note:',row.get('note'))

# %% [markdown]
# ## 3. Scientific Limitations (Evidence-Only)

# %% [markdown]
# - Phase 25B MLP predictions.npy verified (hash: cf6afa609...). Phase 25B MLP checkpoint.pt verified (hash: d8d6613...).
# - Phase 30c executes the actual frozen linear representation audit (MLP only; predictions.npy MISSING prevents full portfolio verification; no predictions fabricated; no reconstructed predictions substituted for missing portfolio predictions).
# - Only approximate overlap/complementarity from Phase 28 artifacts (independence assumption).
# - Scientific case preserved honestly: CASE_D_UNRESOLVED (no validated minimal intervention; predictions MISSING prevents exact complementarity; no architecture change; RC CLOSED; gate CLOSED).
# - Historical Phase 20 replay impossible (predictions.npy original MISSING; split identity UNVERIFIED; checkpoint identity AMBIGUOUS).
